# %%
import numpy as np
first_marks = [12,12,4,1,2,3,5,1,2,3,4,5,1]
minimum, Q1, median, Q3, maximum = np.quantile(first_marks, [0,0.25,0.5,0.75,1])

IQR = Q3-Q1
import seaborn as sns
sns.boxplot(first_marks)
# Out:
# <Axes: >

# %%
minimum, Q1, median, Q3, maximum
# Out:
# (np.float64(1.0),
#  np.float64(2.0),
#  np.float64(3.0),
#  np.float64(5.0),
#  np.float64(12.0))
